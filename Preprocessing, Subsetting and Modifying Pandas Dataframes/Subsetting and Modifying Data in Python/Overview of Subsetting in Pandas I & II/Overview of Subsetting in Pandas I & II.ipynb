# %% [markdown]
# # Overview of Subsetting in Pandas
#
#
#
# **TABLE OF CONTENTS**
#
# - What is an index?
# - How to subset first N rows based on their position index?
# - Can we change the index?
# - will the index be always numeric?
# - How to subset the data based on label of index?
# - Can we reset the index?
# - How to subset the data based on a value of a column?

# %% [markdown]
# READ THE DATA
#
# - In this notebook, we are going to use big mart sales that we have used previously. It is stored in the folder name datasets.

# %%
#import the pandas library
# %pip install pandas==1.5.2
# Out:
# Python interpreter will be restarted.
# ...
# Python interpreter will be restarted.

# %%
import pandas as pd
pd.__version__
# Out:
# Out[1]: '1.5.2'

# %%
dbutils.fs.cp("dbfs:/FileStore/ml/datasets/big_mart_sales.csv", "file:///tmp/datasets/big_mart_sales.csv")
# Out:
# Out[2]: True

# %%
with open('/tmp/datasets/big_mart_sales.csv', 'r') as f:
    text = f.readline()
    print(text)
# Out:
# Item_Identifier,Item_Weight,Item_Fat_Content,Item_Visibility,Item_Type,Item_MRP,Outlet_Identifier,Outlet_Establishment_Year,Outlet_Size,Outlet_Location_Type,Outlet_Type,Item_Outlet_Sales

# %%
#read the big mart sales data

data = pd.read_csv('file:///tmp/datasets/big_mart_sales.csv')

# %%
data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Item_Identifier</th>
#       <th>Item_Weight</th>
#       <th>Item_Fat_Content</th>
#       <th>Item_Visibility</th>
#       <th>Item_Type</th>
#       <th>Item_MRP</th>
#       <th>Outlet_Identifier</th>
#       <th>Outlet_Establishment_Year</th>
#       <th>Outlet_Size</th>
#       <th>Outlet_Location_Type</th>
#       <th>Outlet_Type</th>
#       <th>Item_Outlet_Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>FDA15</td>
#       <td>9.30</td>
#       <td>Low Fat</td>
#       <td>0.016047</td>
#       <td>Dairy</td>
#       <td>249.8092</td>
#       <td>OUT049</td>
# ...

# %%
data.tail()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Item_Identifier</th>
#       <th>Item_Weight</th>
#       <th>Item_Fat_Content</th>
#       <th>Item_Visibility</th>
#       <th>Item_Type</th>
#       <th>Item_MRP</th>
#       <th>Outlet_Identifier</th>
#       <th>Outlet_Establishment_Year</th>
#       <th>Outlet_Size</th>
#       <th>Outlet_Location_Type</th>
#       <th>Outlet_Type</th>
#       <th>Item_Outlet_Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>8518</th>
#       <td>FDF22</td>
#       <td>6.865</td>
#       <td>Low Fat</td>
#       <td>0.056783</td>
#       <td>Snack Foods</td>
#       <td>214.5218</td>
# ...

# %% [markdown]
# - You can see the index object by Dataframe.index

# %%
# index of the dataframe

data.index
# Out:
# Out[7]: RangeIndex(start=0, stop=8523, step=1)

# %% [markdown]
# **So, In this case, we have the numeric index value start from 0 and 8523.**

# %%
# no of rows and columns in the data
data.shape
# Out:
# Out[8]: (8523, 12)

# %%
# column index 

data.columns
# Out:
# Out[9]: Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %% [markdown]
# ####HOW TO SUBSET 'N ROWS' BASED ON THE POSITION INDEX?

# %%
# views the top rows of the data
data.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Item_Identifier</th>
#       <th>Item_Weight</th>
#       <th>Item_Fat_Content</th>
#       <th>Item_Visibility</th>
#       <th>Item_Type</th>
#       <th>Item_MRP</th>
#       <th>Outlet_Identifier</th>
#       <th>Outlet_Establishment_Year</th>
#       <th>Outlet_Size</th>
#       <th>Outlet_Location_Type</th>
#       <th>Outlet_Type</th>
#       <th>Item_Outlet_Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>FDA15</td>
#       <td>9.300</td>
#       <td>Low Fat</td>
#       <td>0.016047</td>
#       <td>Dairy</td>
#       <td>249.8092</td>
#       <td>OUT049</td>
# ...

# %% [markdown]
# **CAN WE CHANGE THE INDEX?**
#
# The answer is Yes, We can change the index, Let's see how?
#
# **Create a random list of 8523 numbers and set it as the index**

# %%
# create random list

import random 

random_list = [random.randint(1, 8523) for i in range(8523)]

# %%
random_list
# Out:
# Out[12]: [3184,
#  7490,
#  3927,
#  1730,
#  4842,
#  6444,
#  1758,
#  1062,
#  3723,
#  6385,
#  919,
#  1937,
#  4755,
#  3228,
#  4060,
#  2694,
#  2650,
#  3370,
#  1068,
#  7895,
#  4669,
#  5072,
#  6644,
#  4881,
#  1404,
#  1056,
#  1389,
#  320,
#  5497,
#  7270,
#  326,
#  2040,
#  1328,
#  7194,
#  6199,
#  3925,
#  5782,
#  4999,
#  7311,
#  4350,
#  586,
#  7188,
#  5406,
#  6857,
#  3842,
#  4443,
#  1630,
#  5376,
#  5517,
#  356,
#  6578,
#  7082,
#  5561,
#  3599,
#  4533,
#  105,
#  6570,
#  4096,
#  8097,
#  4397,
#  2809,
#  374,
#  2487,
#  5587,
#  8522,
#  6710,
#  3763,
#  1523,
#  2525,
#  6348,
#  1204,
#  4578,
#  4327,
#  1350,
#  4791,
#  1350,
#  5748,
#  6800,
#  442,
#  2344,
#  3776,
#  7822,
#  5933,
#  1342,
#  5104,
#  1856,
#  4472,
#  420,
#  6055,
#  5197,
#  99,
#  1383,
#  8468,
#  8137,
#  2623,
#  7176,
#  1873,
#  6453,
#  4115,
#  2076,
#  3264,
#  8100,
#  248,
#  448,
#  611,
#  6587,
#  2849,
#  3712,
#  7623,
#  7210,
#  5740,
# ...

# %%
# set the index

data.index = random_list

# %%
data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Item_Identifier</th>
#       <th>Item_Weight</th>
#       <th>Item_Fat_Content</th>
#       <th>Item_Visibility</th>
#       <th>Item_Type</th>
#       <th>Item_MRP</th>
#       <th>Outlet_Identifier</th>
#       <th>Outlet_Establishment_Year</th>
#       <th>Outlet_Size</th>
#       <th>Outlet_Location_Type</th>
#       <th>Outlet_Type</th>
#       <th>Item_Outlet_Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3184</th>
#       <td>FDA15</td>
#       <td>9.30</td>
#       <td>Low Fat</td>
#       <td>0.016047</td>
#       <td>Dairy</td>
#       <td>249.8092</td>
#       <td>OUT049</td>
# ...

# %% [markdown]
# **Set another coulumn as the index. We will use the set_index function.**

# %%
# 1. change the index of the dataframe
# 2. drop=True is used to dropthe column that's set as index
# 3. inplace=True is used to make changes in the original dataframe


data= pd.read_csv('file:///tmp/datasets/big_mart_sales.csv')

data.set_index('Outlet_Establishment_Year', drop=True, inplace=True)

# %%
# example of a label based index

data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Item_Identifier</th>
#       <th>Item_Weight</th>
#       <th>Item_Fat_Content</th>
#       <th>Item_Visibility</th>
#       <th>Item_Type</th>
#       <th>Item_MRP</th>
#       <th>Outlet_Identifier</th>
#       <th>Outlet_Size</th>
#       <th>Outlet_Location_Type</th>
#       <th>Outlet_Type</th>
#       <th>Item_Outlet_Sales</th>
#     </tr>
#     <tr>
#       <th>Outlet_Establishment_Year</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
# ...

# %%
data.index
# Out:
# Out[19]: Int64Index([1999, 2009, 1999, 1998, 1987, 2009, 1987, 1985, 2002, 2007,
#             ...
#             2004, 2002, 2009, 2009, 1997, 1987, 2002, 2004, 2009, 1997],
#            dtype='int64', name='Outlet_Establishment_Year', length=8523)

# %%
data= pd.read_csv('file:///tmp/datasets/big_mart_sales.csv')

data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Item_Identifier</th>
#       <th>Item_Weight</th>
#       <th>Item_Fat_Content</th>
#       <th>Item_Visibility</th>
#       <th>Item_Type</th>
#       <th>Item_MRP</th>
#       <th>Outlet_Identifier</th>
#       <th>Outlet_Establishment_Year</th>
#       <th>Outlet_Size</th>
#       <th>Outlet_Location_Type</th>
#       <th>Outlet_Type</th>
#       <th>Item_Outlet_Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>FDA15</td>
#       <td>9.30</td>
#       <td>Low Fat</td>
#       <td>0.016047</td>
#       <td>Dairy</td>
#       <td>249.8092</td>
#       <td>OUT049</td>
# ...

# %%
data_updated = data.set_index('Outlet_Establishment_Year', drop=True, inplace=False)

# %%
data_updated.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Item_Identifier</th>
#       <th>Item_Weight</th>
#       <th>Item_Fat_Content</th>
#       <th>Item_Visibility</th>
#       <th>Item_Type</th>
#       <th>Item_MRP</th>
#       <th>Outlet_Identifier</th>
#       <th>Outlet_Size</th>
#       <th>Outlet_Location_Type</th>
#       <th>Outlet_Type</th>
#       <th>Item_Outlet_Sales</th>
#     </tr>
#     <tr>
#       <th>Outlet_Establishment_Year</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
# ...

# %%
data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Item_Identifier</th>
#       <th>Item_Weight</th>
#       <th>Item_Fat_Content</th>
#       <th>Item_Visibility</th>
#       <th>Item_Type</th>
#       <th>Item_MRP</th>
#       <th>Outlet_Identifier</th>
#       <th>Outlet_Establishment_Year</th>
#       <th>Outlet_Size</th>
#       <th>Outlet_Location_Type</th>
#       <th>Outlet_Type</th>
#       <th>Item_Outlet_Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>FDA15</td>
#       <td>9.30</td>
#       <td>Low Fat</td>
#       <td>0.016047</td>
#       <td>Dairy</td>
#       <td>249.8092</td>
#       <td>OUT049</td>
# ...

# %% [markdown]
# **WILL THE INDEX BE ALWAYS NUMERIC?**
#
# **No, We can also have categorical variable as the index of a dataframe.**

# %%
#reset the index
data.set_index('Item_Identifier', drop=True, inplace=True)

# %%
# view the top rows of the data
data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Item_Weight</th>
#       <th>Item_Fat_Content</th>
#       <th>Item_Visibility</th>
#       <th>Item_Type</th>
#       <th>Item_MRP</th>
#       <th>Outlet_Identifier</th>
#       <th>Outlet_Establishment_Year</th>
#       <th>Outlet_Size</th>
#       <th>Outlet_Location_Type</th>
#       <th>Outlet_Type</th>
#       <th>Item_Outlet_Sales</th>
#     </tr>
#     <tr>
#       <th>Item_Identifier</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
# ...

# %%
# index of the data

data.index
# Out:
# Out[32]: Index(['FDA15', 'DRC01', 'FDN15', 'FDX07', 'NCD19', 'FDP36', 'FDO10', 'FDP10',
#        'FDH17', 'FDU28',
#        ...
#        'FDH31', 'FDA01', 'FDH24', 'NCJ19', 'FDF53', 'FDF22', 'FDS36', 'NCJ29',
#        'FDN46', 'DRG01'],
#       dtype='object', name='Item_Identifier', length=8523)

# %% [markdown]
# **HOW TO SUBSET THE DATA BASED ON THE LABEL OF THE INDEX?**
#
# - We can subset the data based on the label of the index using the loc function.

# %%
data.loc['FDA15']
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Item_Weight</th>
#       <th>Item_Fat_Content</th>
#       <th>Item_Visibility</th>
#       <th>Item_Type</th>
#       <th>Item_MRP</th>
#       <th>Outlet_Identifier</th>
#       <th>Outlet_Establishment_Year</th>
#       <th>Outlet_Size</th>
#       <th>Outlet_Location_Type</th>
#       <th>Outlet_Type</th>
#       <th>Item_Outlet_Sales</th>
#     </tr>
#     <tr>
#       <th>Item_Identifier</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
# ...

# %% [markdown]
# ***What if we want to change the back to positional?***
#
# **CAN WE RESET THE THE INDEX?**
#
# ***Yes, we can reset the index. Let's see how? We will use the reset_index function.***

# %%
# reset the index
data.reset_index(inplace=True)

# %%
# view the top rows of the data

data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Item_Identifier</th>
#       <th>Item_Weight</th>
#       <th>Item_Fat_Content</th>
#       <th>Item_Visibility</th>
#       <th>Item_Type</th>
#       <th>Item_MRP</th>
#       <th>Outlet_Identifier</th>
#       <th>Outlet_Establishment_Year</th>
#       <th>Outlet_Size</th>
#       <th>Outlet_Location_Type</th>
#       <th>Outlet_Type</th>
#       <th>Item_Outlet_Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>FDA15</td>
#       <td>9.30</td>
#       <td>Low Fat</td>
#       <td>0.016047</td>
#       <td>Dairy</td>
#       <td>249.8092</td>
#       <td>OUT049</td>
# ...

# %%
data.index
# Out:
# Out[36]: RangeIndex(start=0, stop=8523, step=1)

# %% [markdown]
# **HOW TO SUBSET THE BASED ON A VALUE OF A COLUMN?**

# %%
data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Item_Identifier</th>
#       <th>Item_Weight</th>
#       <th>Item_Fat_Content</th>
#       <th>Item_Visibility</th>
#       <th>Item_Type</th>
#       <th>Item_MRP</th>
#       <th>Outlet_Identifier</th>
#       <th>Outlet_Establishment_Year</th>
#       <th>Outlet_Size</th>
#       <th>Outlet_Location_Type</th>
#       <th>Outlet_Type</th>
#       <th>Item_Outlet_Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>FDA15</td>
#       <td>9.30</td>
#       <td>Low Fat</td>
#       <td>0.016047</td>
#       <td>Dairy</td>
#       <td>249.8092</td>
#       <td>OUT049</td>
# ...

# %%
data[data['Item_Type']=='Dairy']
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Item_Identifier</th>
#       <th>Item_Weight</th>
#       <th>Item_Fat_Content</th>
#       <th>Item_Visibility</th>
#       <th>Item_Type</th>
#       <th>Item_MRP</th>
#       <th>Outlet_Identifier</th>
#       <th>Outlet_Establishment_Year</th>
#       <th>Outlet_Size</th>
#       <th>Outlet_Location_Type</th>
#       <th>Outlet_Type</th>
#       <th>Item_Outlet_Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>FDA15</td>
#       <td>9.300</td>
#       <td>Low Fat</td>
#       <td>0.016047</td>
#       <td>Dairy</td>
#       <td>249.8092</td>
#       <td>OUT049</td>
# ...
